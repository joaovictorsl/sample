# %%
# %pip install requests
# %pip install matplotlib
# %matplotlib inline
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
print("This might be hard to review on github")
# Out:
# This might be hard to review on github

# %% [markdown]
# ### Let's see what happens

# %%
from PIL import Image
import io

image_data = requests.get("https://previews.123rf.com/images/helgidinson/helgidinson1601/helgidinson160100050/51774136-the-star-of-pixar-movie-cars-lightning-mcaquuen.jpg?fj=1")
image = Image.open(io.BytesIO(image_data.content))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1300x867>

# %% [markdown]
# # TWO IMAGES!!!!

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1300x867>
