# %%
# %pip install requests
# %pip install matplotlib
# %matplotlib inline
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 3.1 MB/s eta 0:00:00m eta 0:00:010:00:01m
# ...
#   Using cached contourpy-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 7.8 MB/s eta 0:00:00m eta 0:00:010:00:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 12.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
print("This might be hard to review on github")
# Out:
# This might be hard to review on github

# %% [markdown]
# ### Let's see what happens

# %%
from PIL import Image
import io

image_data = requests.get("https://cdn.britannica.com/16/234216-050-C66F8665/beagle-hound-dog.jpg")
image = Image.open(io.BytesIO(image_data.content))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x1057>

# %% [markdown]
# # TWO IMAGES!!!!

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x1057>
